# %%
from IPython.display import display

from sympy import *
init_printing()

from monomial import *

# %%
t, x, tau, h, s0, s1, s = symbols(r't, x, tau, h, sigma_0, sigma_1, sigma', real=True)
f1, f2 = (f(t, x) for f in symbols(r'{\phi_1}, {\phi_2}', cls=Function))

# %%
pda_f, pda_v = (f1, f2), (t, x)
pda_n, pda_clp = (6, 6), (3, 3)
pda_p = Rational(1, 2), Rational(0, 1)

# %%
pda_var, pda_fun = Monom.init([str(v) for v in pda_v],\
                              [str(f) for f in pda_f])
pda_var = dict(zip(pda_v, pda_var))
pda_fun = dict(zip(pda_f, pda_fun))

# %%
def T(f, i1, j1):
    return sum(sum(\
        diff(f, t, i, x, j)*(tau*(i1 - pda_p[0]))**i \
                             *(h*(j1 - pda_p[1]))**j/\
                 (factorial(i)*factorial(j))\
        for i in range(pda_n[0]))\
        for j in range(pda_n[1]))

# %%
expand((T(f1, 1, 0) - T(f1, 0, 0))/(tau))
# Out:
#      5                        3
#  4  ∂                     2  ∂
# τ ⋅───({\phi_1}(t, x))   τ ⋅───({\phi_1}(t, x))
#      5                        3
#    ∂t                       ∂t                    ∂
# ────────────────────── + ────────────────────── + ──({\phi_1}(t, x))
#          1920                      24             ∂t

# %%
def clip(f):
    f = f.expand()
    r = []
    for i in range(pda_clp[0]):
        for j in range(pda_clp[1]):
            c = f.coeff(tau, i).coeff(h, j)
            if c and (\
            (pda_clp[0]-1 != i or j == 0) and \
            (pda_clp[1]-1 != j or i == 0)):
                r.append(((i, j), c))
    return r

def df2m(a):
    assert a.func == Derivative
    m = pda_fun[a.args[0]]
    for xi in a.args[1:]:
        if isinstance(xi, Symbol):
            m = m*pda_var[xi]
        else:
            m = m*pda_var[xi[0]]**xi[1]
    return m

def m2df(m):
    r = pda_f[m.position()]
    for i in range(len(m)):
        r = r.diff(pda_v[i], m[i])
    return r

def findDiv(a, d):
    r = None
    def find(a, r):
        if a.args:
            if a.func == Derivative and a.args[0] in pda_fun:
                m = df2m(a)
                if m.divisible(d) and (not r or m.cmp(r) > 0):
                    r = m
            else:
                for s in a.args:
                    r = find(s, r)
        return r
    return find(a, r)

def mult(a, s):
    r = []
    for mc in a:
        m = mc[0][0] + s[0], mc[0][1] + s[1]
        if m[0] < pda_clp[0] and m[1] < pda_clp[1] and\
           (pda_clp[0]-1 != m[0] or m[1] == 0) and \
           (pda_clp[1]-1 != m[1] or m[0] == 0):
            r.append((m, mc[1]))
    return r

def add(a, b):
    r, ia, ib = [], 0, 0
    iaend, ibend = len(a), len(b)
    while ia < iaend and ib < ibend:
        ma, mb = a[ia][0], b[ib][0]
        if ma[0] > mb[0]:
            c = 1
        elif ma[0] < mb[0]:
            c = -1
        elif ma[1] > mb[1]:
            c = 1
        elif ma[1] < mb[1]:
            c = -1
        else:
            c = 0
        
        if c == -1:
            r.append(a[ia])
            ia += 1
        elif c == 1:
            r.append(b[ib])
            ib += 1
        else:
            d = expand(a[ia][1] + b[ib][1])
            if d:
                r.append((ma, d))
            ia += 1
            ib += 1
    while ia < iaend:
        r.append(a[ia])
        ia += 1
    while ib < ibend:
        r.append(b[ib])
        ib += 1
    return r

def reduction(f1, f2, m, c, shift):
#     print(m, c, shift)
    f = mult(f2, shift)
    if not m:
        f = [(s, c*p) for s, p in f]
    else:
        f = [(s, c*p.diff(*m)) for s, p in f]
    return add(f1, f)

def NF(f, df, G, head=False):
    assert len(df) == len(G)
    ms = [df2m(d) for d in df]
    i = 0 if head else 1
    while i < len(f):
        shift, p = f[i]
        while True:
            r = None
            for l in range(len(ms)):
                r = findDiv(p, ms[l])
                if r:
                    break
            if not r: 
                break
            m = m2df(r)
            deg = p.as_poly(m).degree()
            c = p.coeff(m, deg)
            if deg > 1:
                c = p.coeff(m, deg)*m**(deg - 1)
            m = r/ms[l]
            d = []
            for k in range(len(pda_v)):
                if m[k] > 0:
                    d.append(pda_v[k])
                    if m[k] > 1:
                        d.append(m[k])
            f = reduction(f, G[l], tuple(d), -c/G[l][0][1].coeff(df[l]), shift)
            if i == len(f):
                break
            shift, p = f[i]
        i += 1
    return f

def compact(f):
    def cmpct(a):
        if not a.args:
            return a
        else:
            if a in pda_f:
                return Symbol("%s" % a.func, real=True)
            elif a.func == Derivative:
                m = []
                for xi in a.args[1:]:
                    if isinstance(xi, Symbol):
                        m.append(str(xi))
                    else:
                        m.append(str(xi[0])*xi[1])
                return Symbol("%s_{%s}" % (a.args[0].func, "".join(m)), real=True)
            else:
                return a.func(*tuple(cmpct(s) for s in a.args))
    return cmpct(f)

def prn(a, p=None):
    for m, c in a:
        s = ""
        if m[0]:
            if m[0] == 1:
                s += "tau"
            else:
                s += "tau^%d" % m[0]
        if m[1]:
            if m[0]:
                s += " "
            if m[1] == 1:
                s += "h"
            else:
                s += "h^%d" % m[1]
        if s:
            print("%s =>" % s)
        if p:
            display(compact(c).collect(p, factor))
        else:
            display(compact(c))

def prnlatex(a, p=None):
    first = True
    for m, c in a:
        s = ""
        if m[0]:
            if m[0] == 1:
                s += r"\tau"
            else:
                s += r"\tau^%d" % m[0]
        if m[1]:
            if m[0]:
                s += " "
            if m[1] == 1:
                s += "h"
            else:
                s += r"h^%d" % m[1]
        if s:
            if first:
                first = False
                print(r"%s\Big(" % s)
            else:
                print(r" + %s\Big(" % s)
        if p:
            print(latex(compact(c).collect(p, factor)))
        else:
            print(latex(compact(c)))
        if first:
            first = False
        else:
            print(r"\Big)")

# %% [markdown]
# # Физически нелинейные соосные упругие цилиндрические оболочки, заполненные вязкой несжимаемой жидкостью, включая внутреннюю оболочку
# \begin{equation}\label{Blin_eq7a}
#   \begin{split}
#     \phi_t^{(1)}&+6\sigma_0\phi^{(1)}\phi_\eta^{(1)}+\phi_{\eta\eta\eta}^{(1)}\mp
# 6\sigma_1{\phi^{(1)}}^2\phi_\eta^{(1)}+
#       \phi^{(1)}-\phi^{(2)}=0,\\
#     \phi_t^{(2)}&+6\sigma_0\phi^{(2)}\phi_\eta^{(2)}+\phi_{\eta\eta\eta}^{(2)}\mp
# 6\sigma_1{\phi^{(2)}}^2\phi_\eta^{(2)}+
#       \phi^{(2)}-\phi^{(1)} - \sigma \phi^{(2)} =0,
#   \end{split}
# \end{equation}

# %%
def Dt(a):
    return (T(a, 1, 0) - T(a, 0, 0))/(tau)
def Dx(a):
    return ((T(a, 1, 1) - T(a, 1, -1))/(2*h) +\
            (T(a, 0, 1) - T(a, 0, -1))/(2*h))/2
def Dxxx(a):
    return ((T(a, 1, 2) - 2*T(a, 1, 1) + 2*T(a, 1, -1) - T(a, 1, -2))/(2*h**3) +\
            (T(a, 0, 2) - 2*T(a, 0, 1) + 2*T(a, 0, -1) - T(a, 0, -2))/(2*h**3))/2

# %%
Monom.cmp = Monom.TOPlex

# %%
F1 = clip(Dt(f1) + 3*s0*Dx(f1**2) + 2*s1*Dx(f1**3) + Dxxx(f1) +\
          (T(f1 - f2, 1, 0) + T(f1 - f2, 0, 0))/2)
prn(F1)
# prnlatex(F1)
# Out:
#                                           2
# 6⋅σ₀⋅{\phi_1}⋅{\phi_1}_{x} + 6⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x} + {\phi_1} + {\phi_1}_{t} + {\phi_
#
#
# 1}_{xxx} - {\phi_2}
# h^2 =>
#                                                                           2
# σ₀⋅{\phi_1}⋅{\phi_1}_{xxx} + 3⋅σ₀⋅{\phi_1}_{xx}⋅{\phi_1}_{x} + σ₁⋅{\phi_1} ⋅{\phi_1}_{xxx}
#
#
#                                                               3   {\phi_1}_{xxxxx}
# + 6⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xx}⋅{\phi_1}_{x} + 2⋅σ₁⋅{\phi_1}_{x}  + ────────────────
#                                                                          4
# tau^2 =>
#
# 3⋅σ₀⋅{\phi_1}⋅{\phi_1}_{ttx}   3⋅σ₀⋅{\phi_1}_{tt}⋅{\phi_1}_{x}   3⋅σ₀⋅{\phi_1}_{tx}⋅{\phi_1
# ──────────────────────────── + ─────────────────────────────── + ──────────────────────────
#              4                                4                                 2
#
#                      2
# }_{t}   3⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{ttx}   3⋅σ₁⋅{\phi_1}⋅{\phi_1}_{tt}⋅{\phi_1}_{x}
# ───── + ───────────────────────────── + ──────────────────────────────────────── + 3⋅σ₁⋅{\p
#                       4                                    2
#
#                                                     2
#                                    3⋅σ₁⋅{\phi_1}_{t} ⋅{\phi_1}_{x}   {\phi_1}_{ttt}   {\phi
# hi_1}⋅{\phi_1}_{tx}⋅{\phi_1}_{t} + ─────────────────────────────── + ────────────── + ─────
#                                                   2                        24
#
#
# _1}_{ttxxx}   {\phi_1}_{tt}   {\phi_2}_{tt}
# ─────────── + ───────────── - ─────────────
#   8                 8               8

# %%
F2 = clip(Dt(f2) + 3*s0*Dx(f2**2) + 2*s1*Dx(f2**3) + Dxxx(f2) +\
          (T(f2 - f1 + s*f2, 1, 0) + T(f2 - f1 + s*f2, 0, 0))/2)
prn(F2)
# prnlatex(F2)
# Out:
#                                                        2
# σ⋅{\phi_2} + 6⋅σ₀⋅{\phi_2}⋅{\phi_2}_{x} + 6⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x} - {\phi_1} + {\phi_2}
#
#
#  + {\phi_2}_{t} + {\phi_2}_{xxx}
# h^2 =>
#                                                                           2
# σ₀⋅{\phi_2}⋅{\phi_2}_{xxx} + 3⋅σ₀⋅{\phi_2}_{xx}⋅{\phi_2}_{x} + σ₁⋅{\phi_2} ⋅{\phi_2}_{xxx}
#
#
#                                                               3   {\phi_2}_{xxxxx}
# + 6⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xx}⋅{\phi_2}_{x} + 2⋅σ₁⋅{\phi_2}_{x}  + ────────────────
#                                                                          4
# tau^2 =>
#
# σ⋅{\phi_2}_{tt}   3⋅σ₀⋅{\phi_2}⋅{\phi_2}_{ttx}   3⋅σ₀⋅{\phi_2}_{tt}⋅{\phi_2}_{x}   3⋅σ₀⋅{\p
# ─────────────── + ──────────────────────────── + ─────────────────────────────── + ────────
#        8                       4                                4
#
#                                        2
# hi_2}_{tx}⋅{\phi_2}_{t}   3⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{ttx}   3⋅σ₁⋅{\phi_2}⋅{\phi_2}_{tt}⋅{\phi
# ─────────────────────── + ───────────────────────────── + ─────────────────────────────────
#        2                                4                                    2
#
#                                                                       2
# _2}_{x}                                              3⋅σ₁⋅{\phi_2}_{t} ⋅{\phi_2}_{x}   {\ph
# ─────── + 3⋅σ₁⋅{\phi_2}⋅{\phi_2}_{tx}⋅{\phi_2}_{t} + ─────────────────────────────── - ────
#                                                                     2
#
#
# i_1}_{tt}   {\phi_2}_{ttt}   {\phi_2}_{ttxxx}   {\phi_2}_{tt}
# ───────── + ────────────── + ──────────────── + ─────────────
#   8               24                8                 8

# %%
F1fda = NF(F1, [f1.diff(t), f2.diff(t)], [F1, F2], head=False)
prn(F1fda)
# prnlatex(F1fda)
print(len(F1fda[1][1].args))
print(len(F1fda[2][1].args))
# Out:
#                                           2
# 6⋅σ₀⋅{\phi_1}⋅{\phi_1}_{x} + 6⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x} + {\phi_1} + {\phi_1}_{t} + {\phi_
#
#
# 1}_{xxx} - {\phi_2}
# h^2 =>
#                                                                           2
# σ₀⋅{\phi_1}⋅{\phi_1}_{xxx} + 3⋅σ₀⋅{\phi_1}_{xx}⋅{\phi_1}_{x} + σ₁⋅{\phi_1} ⋅{\phi_1}_{xxx}
#
#
#                                                               3   {\phi_1}_{xxxxx}
# + 6⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xx}⋅{\phi_1}_{x} + 2⋅σ₁⋅{\phi_1}_{x}  + ────────────────
#                                                                          4
# tau^2 =>
#    2
#   σ ⋅{\phi_2}   σ⋅σ₀⋅{\phi_1}⋅{\phi_2}_{x}   σ⋅σ₀⋅{\phi_1}_{x}⋅{\phi_2}   3⋅σ⋅σ₀⋅{\phi_2}⋅{
# - ─────────── - ────────────────────────── - ────────────────────────── - ─────────────────
#        12                   2                            2                             2
#
#                            2
# \phi_2}_{x}   σ⋅σ₁⋅{\phi_1} ⋅{\phi_2}_{x}
# ─────────── - ─────────────────────────── - σ⋅σ₁⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi_2} - 2⋅σ⋅σ₁⋅{\
#                            2
#
#
#       2                σ⋅{\phi_1}   σ⋅{\phi_2}   σ⋅{\phi_2}_{xxx}        3         3
# phi_2} ⋅{\phi_2}_{x} + ────────── - ────────── - ──────────────── + 18⋅σ₀ ⋅{\phi_1} ⋅{\phi_
#                            12           4               4
#
#
#                  3         2                                    3                      3
# 1}_{xxx} + 162⋅σ₀ ⋅{\phi_1} ⋅{\phi_1}_{xx}⋅{\phi_1}_{x} + 108⋅σ₀ ⋅{\phi_1}⋅{\phi_1}_{x}  +
#
#
#
#      2            4                        2            3
# 54⋅σ₀ ⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xxx} + 648⋅σ₀ ⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xx}⋅{\phi_1}_{x} + 648⋅
#
#
#
#   2            2             3       2         2                         2         2
# σ₀ ⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x}  + 9⋅σ₀ ⋅{\phi_1} ⋅{\phi_1}_{xxxxx} + 18⋅σ₀ ⋅{\phi_1} ⋅{\phi_
#
#
#
#               2         2                      2
# 1}_{xx} - 3⋅σ₀ ⋅{\phi_1} ⋅{\phi_2}_{xx} + 63⋅σ₀ ⋅{\phi_1}⋅{\phi_1}_{xxxx}⋅{\phi_1}_{x} + 99
#
#
#
#    2                                             2                                        2
# ⋅σ₀ ⋅{\phi_1}⋅{\phi_1}_{xxx}⋅{\phi_1}_{xx} - 9⋅σ₀ ⋅{\phi_1}⋅{\phi_1}_{xx}⋅{\phi_2} + 36⋅σ₀
#
#
#
#                       2        2                                          2
# ⋅{\phi_1}⋅{\phi_1}_{x}  - 15⋅σ₀ ⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi_2}_{x} - 3⋅σ₀ ⋅{\phi_1}⋅{\phi_
#
#
#
#                        2                      2        2                            2
# 2}⋅{\phi_2}_{xx} - 3⋅σ₀ ⋅{\phi_1}⋅{\phi_2}_{x}  + 81⋅σ₀ ⋅{\phi_1}_{xxx}⋅{\phi_1}_{x}  + 99⋅
#
#
#
#   2              2                    2             2                2
# σ₀ ⋅{\phi_1}_{xx} ⋅{\phi_1}_{x} - 9⋅σ₀ ⋅{\phi_1}_{x} ⋅{\phi_2} - 3⋅σ₀ ⋅{\phi_1}_{x}⋅{\phi_2
#
#
#
#                      2         2                     2                      2           2
# }⋅{\phi_2}_{x} - 3⋅σ₀ ⋅{\phi_2} ⋅{\phi_2}_{xx} - 6⋅σ₀ ⋅{\phi_2}⋅{\phi_2}_{x}  + 54⋅σ₀⋅σ₁ ⋅{
#
#
#
#        5                           2         4                                        2
# \phi_1} ⋅{\phi_1}_{xxx} + 810⋅σ₀⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{xx}⋅{\phi_1}_{x} + 1080⋅σ₀⋅σ₁ ⋅{\p
#
#
#
#      3             3                    3                                     3
# hi_1} ⋅{\phi_1}_{x}  + 18⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xxxxx} + 45⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x
#
#
#
#                      3                                   2
# x} - 6⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_2}_{xx} + 189⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xxxx}⋅{\phi_1}_{x} + 2
#
#
#
#                  2                                                 2
# 97⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xxx}⋅{\phi_1}_{xx} - 27⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xx}⋅{\phi_2}
#
#
#
#                      2             2                    2
#  + 135⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x}  - 45⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x}⋅{\phi_2}_{x} - 3⋅σ₀⋅
#
#
#
#            2                                          2             2
# σ₁⋅{\phi_1} ⋅{\phi_2}⋅{\phi_2}_{xx} - 3⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_2}_{x}  + 522⋅σ₀⋅σ₁⋅{\phi_1}⋅
#
#
#
#                            2                                   2
# {\phi_1}_{xxx}⋅{\phi_1}_{x}  + 666⋅σ₀⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xx} ⋅{\phi_1}_{x} - 54⋅σ₀⋅σ₁⋅{\
#
#
#
#                    2
# phi_1}⋅{\phi_1}_{x} ⋅{\phi_2} - 6⋅σ₀⋅σ₁⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi_2}⋅{\phi_2}_{x} - 3⋅σ₀⋅
#
#
#
#                     2                                                       2
# σ₁⋅{\phi_1}⋅{\phi_2} ⋅{\phi_2}_{xx} - 6⋅σ₀⋅σ₁⋅{\phi_1}⋅{\phi_2}⋅{\phi_2}_{x}  + 396⋅σ₀⋅σ₁⋅{
#
#
#
#                          3                                2
# \phi_1}_{xx}⋅{\phi_1}_{x}  - 3⋅σ₀⋅σ₁⋅{\phi_1}_{x}⋅{\phi_2} ⋅{\phi_2}_{x} - 6⋅σ₀⋅σ₁⋅{\phi_2}
#
#
#
# 3                                  2             2   3⋅σ₀⋅{\phi_1}⋅{\phi_1}_{xxxxxxx}   9⋅σ
#  ⋅{\phi_2}_{xx} - 18⋅σ₀⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x}  + ──────────────────────────────── + ───
#                                                                     2
#
#
# ₀⋅{\phi_1}⋅{\phi_1}_{xxxx}                                3⋅σ₀⋅{\phi_1}⋅{\phi_2}_{xxxx}
# ────────────────────────── + 5⋅σ₀⋅{\phi_1}⋅{\phi_1}_{x} - ───────────────────────────── - 2
#            2                                                            2
#
#
#                                                                   27⋅σ₀⋅{\phi_1}_{xxxxx}⋅{\
# ⋅σ₀⋅{\phi_1}⋅{\phi_2}_{x} + 6⋅σ₀⋅{\phi_1}_{xxxxxx}⋅{\phi_1}_{x} + ─────────────────────────
#                                                                                    2
#
#
# phi_1}_{xx}                                          3⋅σ₀⋅{\phi_1}_{xxxx}⋅{\phi_2}   21⋅σ₀⋅
# ─────────── + 21⋅σ₀⋅{\phi_1}_{xxxx}⋅{\phi_1}_{xxx} - ───────────────────────────── + ──────
#                                                                    2
#
#
# {\phi_1}_{xxx}⋅{\phi_1}_{x}                                                        2
# ─────────────────────────── - 3⋅σ₀⋅{\phi_1}_{xxx}⋅{\phi_2}_{x} + 6⋅σ₀⋅{\phi_1}_{xx}  - 3⋅σ₀
#           2
#
#
#
# ⋅{\phi_1}_{xx}⋅{\phi_2}_{xx} - 2⋅σ₀⋅{\phi_1}_{x}⋅{\phi_2} - 3⋅σ₀⋅{\phi_1}_{x}⋅{\phi_2}_{xxx
#
#
#
#     3⋅σ₀⋅{\phi_2}⋅{\phi_2}_{xxxx}                              9⋅σ₀⋅{\phi_2}_{xxx}⋅{\phi_2}
# } - ───────────────────────────── - σ₀⋅{\phi_2}⋅{\phi_2}_{x} - ────────────────────────────
#                   2                                                           2
#
#
# _{x}                     2        3         6                        3         5
# ──── - 3⋅σ₀⋅{\phi_2}_{xx}  + 18⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{xxx} + 324⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{
#
#
#
#                          3         4             3       2         4
# xx}⋅{\phi_1}_{x} + 540⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{x}  + 9⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{xxxxx} + 27⋅
#
#
#
#   2         4                     2         4                       2         3
# σ₁ ⋅{\phi_1} ⋅{\phi_1}_{xx} - 3⋅σ₁ ⋅{\phi_1} ⋅{\phi_2}_{xx} + 126⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{x
#
#
#
#                           2         3                                     2         3
# xxx}⋅{\phi_1}_{x} + 198⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{xxx}⋅{\phi_1}_{xx} - 18⋅σ₁ ⋅{\phi_1} ⋅{\phi
#
#
#
#                           2         3             2        2         3
# _1}_{xx}⋅{\phi_2} + 108⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{x}  - 30⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{x}⋅{\phi_2
#
#
#
#               2         2                            2         2         2              2
# }_{x} + 522⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{xxx}⋅{\phi_1}_{x}  + 666⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{xx} ⋅{
#
#
#
#                    2         2             2                2         2         2
# \phi_1}_{x} - 54⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{x} ⋅{\phi_2} - 3⋅σ₁ ⋅{\phi_1} ⋅{\phi_2} ⋅{\phi_2}_
#
#
#
#            2         2                      2         2
# {xx} - 6⋅σ₁ ⋅{\phi_1} ⋅{\phi_2}⋅{\phi_2}_{x}  + 792⋅σ₁ ⋅{\phi_1}⋅{\phi_1}_{xx}⋅{\phi_1}_{x}
#
#
#
# 3       2                               2                     2             5       2
#   - 6⋅σ₁ ⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi_2} ⋅{\phi_2}_{x} + 72⋅σ₁ ⋅{\phi_1}_{x}  - 3⋅σ₁ ⋅{\phi
#
#
#                                                                    2
#    4                      2         3             2   3⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xxxxxxx}
# _2} ⋅{\phi_2}_{xx} - 12⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{x}  + ───────────────────────────────── + 6
#                                                                       2
#
#                                               2                             2
#             2                   17⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x}   3⋅σ₁⋅{\phi_1} ⋅{\phi_2}_{xxx
# ⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xxxx} + ──────────────────────────── - ────────────────────────────
#                                              2                               2
#
#                   2
# x}   7⋅σ₁⋅{\phi_1} ⋅{\phi_2}_{x}
# ── - ─────────────────────────── + 12⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xxxxxx}⋅{\phi_1}_{x} + 27⋅σ₁⋅{\
#                   2
#
#
#
# phi_1}⋅{\phi_1}_{xxxxx}⋅{\phi_1}_{xx} + 42⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xxxx}⋅{\phi_1}_{xxx} - 3⋅σ
#
#
#
#
# ₁⋅{\phi_1}⋅{\phi_1}_{xxxx}⋅{\phi_2} + 27⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xxx}⋅{\phi_1}_{x} - 6⋅σ₁⋅{\p
#
#
#
#                                                                 2
# hi_1}⋅{\phi_1}_{xxx}⋅{\phi_2}_{x} + 15⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xx}  - 6⋅σ₁⋅{\phi_1}⋅{\phi_1}_
#
#
#
#
# {xx}⋅{\phi_2}_{xx} - 7⋅σ₁⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi_2} - 6⋅σ₁⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi
#
#
#
#                                                                                      2
# _2}_{xxx} + 3⋅σ₁⋅{\phi_1}⋅{\phi_2}⋅{\phi_2}_{x} + 27⋅σ₁⋅{\phi_1}_{xxxxx}⋅{\phi_1}_{x}  + 11
#
#
#
#                                                                       2
# 7⋅σ₁⋅{\phi_1}_{xxxx}⋅{\phi_1}_{xx}⋅{\phi_1}_{x} + 75⋅σ₁⋅{\phi_1}_{xxx} ⋅{\phi_1}_{x} + 108⋅
#
#
#
#                                2
# σ₁⋅{\phi_1}_{xxx}⋅{\phi_1}_{xx}  - 6⋅σ₁⋅{\phi_1}_{xxx}⋅{\phi_1}_{x}⋅{\phi_2} - 3⋅σ₁⋅{\phi_1
#
#
#
#       2                                            2
# }_{xx} ⋅{\phi_2} + 30⋅σ₁⋅{\phi_1}_{xx}⋅{\phi_1}_{x}  - 12⋅σ₁⋅{\phi_1}_{xx}⋅{\phi_1}_{x}⋅{\p
#
#
#                                                                          2                2
#                              2                 3⋅σ₁⋅{\phi_1}_{x}⋅{\phi_2}    3⋅σ₁⋅{\phi_2}
# hi_2}_{x} - 6⋅σ₁⋅{\phi_1}_{x} ⋅{\phi_2}_{xx} + ─────────────────────────── - ──────────────
#                                                             2
#
#                                 2
# ⋅{\phi_2}_{xxxx}   5⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x}
# ──────────────── - ─────────────────────────── - 9⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xxx}⋅{\phi_2}_{x}
# 2                               2
#
#
#                              2                                   2   {\phi_1}   {\phi_1}_{x
# - 6⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xx}  - 12⋅σ₁⋅{\phi_2}_{xx}⋅{\phi_2}_{x}  + ──────── + ───────────
#                                                                         3                12
#
#
# xxxxxxxx}   {\phi_1}_{xxxxxx}   {\phi_1}_{xxx}   {\phi_2}   {\phi_2}_{xxxxxx}   {\phi_2}_{x
# ───────── + ───────────────── + ────────────── - ──────── - ───────────────── - ───────────
#                     4                 2             3               4                 2
#
#
# xx}
# ───
# 6
# 133

# %%
F2fda = NF(F2, [f1.diff(t), f2.diff(t)], [F1, F2], head=False)
prn(F2fda)
# prnlatex(F2fda)
print(len(F2fda[1][1].args))
print(len(F2fda[2][1].args))
# Out:
#                                                        2
# σ⋅{\phi_2} + 6⋅σ₀⋅{\phi_2}⋅{\phi_2}_{x} + 6⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x} - {\phi_1} + {\phi_2}
#
#
#  + {\phi_2}_{t} + {\phi_2}_{xxx}
# h^2 =>
#                                                                           2
# σ₀⋅{\phi_2}⋅{\phi_2}_{xxx} + 3⋅σ₀⋅{\phi_2}_{xx}⋅{\phi_2}_{x} + σ₁⋅{\phi_2} ⋅{\phi_2}_{xxx}
#
#
#                                                               3   {\phi_2}_{xxxxx}
# + 6⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xx}⋅{\phi_2}_{x} + 2⋅σ₁⋅{\phi_2}_{x}  + ────────────────
#                                                                          4
# tau^2 =>
#  3               2                                2            2                 2
# σ ⋅{\phi_2}   7⋅σ ⋅σ₀⋅{\phi_2}⋅{\phi_2}_{x}   13⋅σ ⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x}   σ ⋅{\phi_1}
# ─────────── + ───────────────────────────── + ─────────────────────────────── - ───────────
#      12                     2                                2                       12
#
#     2             2
#    σ ⋅{\phi_2}   σ ⋅{\phi_2}_{xxx}          2         2                        2
#  + ─────────── + ───────────────── + 18⋅σ⋅σ₀ ⋅{\phi_2} ⋅{\phi_2}_{xx} + 36⋅σ⋅σ₀ ⋅{\phi_2}⋅{
#         4                4
#
#
#            2                      3                                     2             2   σ
# \phi_2}_{x}  + 45⋅σ⋅σ₀⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{xx} + 135⋅σ⋅σ₀⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x}  - ─
#
#
#
# ⋅σ₀⋅{\phi_1}⋅{\phi_1}_{x}                                                                 9
# ───────────────────────── - 2⋅σ⋅σ₀⋅{\phi_1}⋅{\phi_2}_{x} - 2⋅σ⋅σ₀⋅{\phi_1}_{x}⋅{\phi_2} + ─
#            2
#
#
# ⋅σ⋅σ₀⋅{\phi_2}⋅{\phi_2}_{xxxx}                                  21⋅σ⋅σ₀⋅{\phi_2}_{xxx}⋅{\ph
# ────────────────────────────── + 7⋅σ⋅σ₀⋅{\phi_2}⋅{\phi_2}_{x} + ───────────────────────────
#               2                                                                  2
#
#
# i_2}_{x}                       2          2         4                         2         3
# ──────── + 6⋅σ⋅σ₀⋅{\phi_2}_{xx}  + 27⋅σ⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{xx} + 108⋅σ⋅σ₁ ⋅{\phi_2} ⋅{
#
#
#                             2
#            2   σ⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x}
# \phi_2}_{x}  - ─────────────────────────── - 6⋅σ⋅σ₁⋅{\phi_1}⋅{\phi_2}⋅{\phi_2}_{x} - 3⋅σ⋅σ₁
#                             2
#
#
#                       2                  2                                   2
# ⋅{\phi_1}_{x}⋅{\phi_2}  + 6⋅σ⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{xxxx} + 13⋅σ⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x}
#
#
#
#                                                                                 2
#  + 27⋅σ⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xxx}⋅{\phi_2}_{x} + 15⋅σ⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xx}  + 30⋅σ⋅σ₁
#
#
#
#                            2   σ⋅{\phi_1}   σ⋅{\phi_1}_{xxx}   5⋅σ⋅{\phi_2}   σ⋅{\phi_2}_{x
# ⋅{\phi_2}_{xx}⋅{\phi_2}_{x}  - ────────── - ──────────────── + ──────────── + ─────────────
#                                    4               4                12                 4
#
#
# xxxxx}   σ⋅{\phi_2}_{xxx}        3         3                        3         2
# ────── + ──────────────── + 18⋅σ₀ ⋅{\phi_2} ⋅{\phi_2}_{xxx} + 162⋅σ₀ ⋅{\phi_2} ⋅{\phi_2}_{x
#                 2
#
#
#                         3                      3        2            4
# x}⋅{\phi_2}_{x} + 108⋅σ₀ ⋅{\phi_2}⋅{\phi_2}_{x}  + 54⋅σ₀ ⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{xxx} + 648
#
#
#
#    2            3                                    2            2             3       2
# ⋅σ₀ ⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{xx}⋅{\phi_2}_{x} + 648⋅σ₀ ⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x}  - 3⋅σ₀ ⋅{
#
#
#
#        2                     2                                       2
# \phi_1} ⋅{\phi_1}_{xx} - 3⋅σ₀ ⋅{\phi_1}⋅{\phi_1}_{xx}⋅{\phi_2} - 6⋅σ₀ ⋅{\phi_1}⋅{\phi_1}_{x
#
#
#
#  2       2                                          2
# }  - 3⋅σ₀ ⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi_2}_{x} - 9⋅σ₀ ⋅{\phi_1}⋅{\phi_2}⋅{\phi_2}_{xx} - 9⋅σ
#
#
#
#  2                      2       2                       2       2             2
# ₀ ⋅{\phi_1}⋅{\phi_2}_{x}  - 3⋅σ₀ ⋅{\phi_1}_{xx}⋅{\phi_2}  - 3⋅σ₀ ⋅{\phi_1}_{x} ⋅{\phi_2} -
#
#
#
#      2                                          2         2                         2
# 15⋅σ₀ ⋅{\phi_1}_{x}⋅{\phi_2}⋅{\phi_2}_{x} + 9⋅σ₀ ⋅{\phi_2} ⋅{\phi_2}_{xxxxx} + 18⋅σ₀ ⋅{\phi
#
#
#
#    2                      2                                              2
# _2} ⋅{\phi_2}_{xx} + 63⋅σ₀ ⋅{\phi_2}⋅{\phi_2}_{xxxx}⋅{\phi_2}_{x} + 99⋅σ₀ ⋅{\phi_2}⋅{\phi_2
#
#
#
#                              2                      2        2                            2
# }_{xxx}⋅{\phi_2}_{xx} + 36⋅σ₀ ⋅{\phi_2}⋅{\phi_2}_{x}  + 81⋅σ₀ ⋅{\phi_2}_{xxx}⋅{\phi_2}_{x}
#
#
#
#         2              2                        2         5                           2
#  + 99⋅σ₀ ⋅{\phi_2}_{xx} ⋅{\phi_2}_{x} + 54⋅σ₀⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{xxx} + 810⋅σ₀⋅σ₁ ⋅{\p
#
#
#
#      4                                        2         3             3                   3
# hi_2} ⋅{\phi_2}_{xx}⋅{\phi_2}_{x} + 1080⋅σ₀⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{x}  - 6⋅σ₀⋅σ₁⋅{\phi_1}
#
#
#
#                                  2                                           2
# ⋅{\phi_1}_{xx} - 3⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xx}⋅{\phi_2} - 18⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x}
#
#
#
# 2                   2                                                                    2
#   - 3⋅σ₀⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x}⋅{\phi_2}_{x} - 3⋅σ₀⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xx}⋅{\phi_2}
#
#
#
#                                2
# - 6⋅σ₀⋅σ₁⋅{\phi_1}⋅{\phi_1}_{x} ⋅{\phi_2} - 6⋅σ₀⋅σ₁⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi_2}⋅{\phi_2}
#
#
#
#                                  2                                                        2
# _{x} - 27⋅σ₀⋅σ₁⋅{\phi_1}⋅{\phi_2} ⋅{\phi_2}_{xx} - 54⋅σ₀⋅σ₁⋅{\phi_1}⋅{\phi_2}⋅{\phi_2}_{x}
#
#
#
#                                  3                       2         2
#  - 6⋅σ₀⋅σ₁⋅{\phi_1}_{xx}⋅{\phi_2}  - 3⋅σ₀⋅σ₁⋅{\phi_1}_{x} ⋅{\phi_2}  - 45⋅σ₀⋅σ₁⋅{\phi_1}_{x
#
#
#
#           2                                 3                                     3
# }⋅{\phi_2} ⋅{\phi_2}_{x} + 18⋅σ₀⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{xxxxx} + 45⋅σ₀⋅σ₁⋅{\phi_2} ⋅{\phi_2
#
#
#
#                            2                                                  2
# }_{xx} + 189⋅σ₀⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{xxxx}⋅{\phi_2}_{x} + 297⋅σ₀⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x
#
#
#
#                                       2             2
# xx}⋅{\phi_2}_{xx} + 135⋅σ₀⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x}  + 522⋅σ₀⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xxx}⋅{
#
#
#
#            2                                   2
# \phi_2}_{x}  + 666⋅σ₀⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xx} ⋅{\phi_2}_{x} + 396⋅σ₀⋅σ₁⋅{\phi_2}_{xx}⋅{\p
#
#
#
#          3   3⋅σ₀⋅{\phi_1}⋅{\phi_1}_{xxxx}                              3⋅σ₀⋅{\phi_1}⋅{\phi
# hi_2}_{x}  - ───────────────────────────── - σ₀⋅{\phi_1}⋅{\phi_1}_{x} - ───────────────────
#                            2                                                          2
#
#
# _2}_{xxxx}                                3⋅σ₀⋅{\phi_1}_{xxxx}⋅{\phi_2}   9⋅σ₀⋅{\phi_1}_{xx
# ────────── - 2⋅σ₀⋅{\phi_1}⋅{\phi_2}_{x} - ───────────────────────────── - ─────────────────
#                                                         2                                2
#
#
# x}⋅{\phi_1}_{x}                                                        2
# ─────────────── - 3⋅σ₀⋅{\phi_1}_{xxx}⋅{\phi_2}_{x} - 3⋅σ₀⋅{\phi_1}_{xx}  - 3⋅σ₀⋅{\phi_1}_{x
#
#
#
#                                                                                    3⋅σ₀⋅{\p
# x}⋅{\phi_2}_{xx} - 2⋅σ₀⋅{\phi_1}_{x}⋅{\phi_2} - 3⋅σ₀⋅{\phi_1}_{x}⋅{\phi_2}_{xxx} + ────────
#
#
#
# hi_2}⋅{\phi_2}_{xxxxxxx}   9⋅σ₀⋅{\phi_2}⋅{\phi_2}_{xxxx}
# ──────────────────────── + ───────────────────────────── + 5⋅σ₀⋅{\phi_2}⋅{\phi_2}_{x} + 6⋅σ
#        2                                 2
#
#
#                                    27⋅σ₀⋅{\phi_2}_{xxxxx}⋅{\phi_2}_{xx}
# ₀⋅{\phi_2}_{xxxxxx}⋅{\phi_2}_{x} + ──────────────────────────────────── + 21⋅σ₀⋅{\phi_2}_{x
#                                                     2
#
#
#                       21⋅σ₀⋅{\phi_2}_{xxx}⋅{\phi_2}_{x}                     2        3
# xxx}⋅{\phi_2}_{xxx} + ───────────────────────────────── + 6⋅σ₀⋅{\phi_2}_{xx}  + 18⋅σ₁ ⋅{\ph
#                                       2
#
#
#     6                        3         5                                    3         4
# i_2} ⋅{\phi_2}_{xxx} + 324⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{xx}⋅{\phi_2}_{x} + 540⋅σ₁ ⋅{\phi_2} ⋅{\p
#
#
#
#          3       2         4                      2         3             2       2
# hi_2}_{x}  - 3⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{xx} - 12⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{x}  - 3⋅σ₁ ⋅{\phi_1
#
#
#
#  2                       2       2         2                                          2
# } ⋅{\phi_1}_{xx}⋅{\phi_2}  - 6⋅σ₁ ⋅{\phi_1} ⋅{\phi_1}_{x}⋅{\phi_2}⋅{\phi_2}_{x} - 6⋅σ₁ ⋅{\p
#
#
#
#                   2         2        2                  3                      2
# hi_1}⋅{\phi_1}_{x} ⋅{\phi_2}  - 18⋅σ₁ ⋅{\phi_1}⋅{\phi_2} ⋅{\phi_2}_{xx} - 54⋅σ₁ ⋅{\phi_1}⋅{
#
#
#
#        2             2       2                       4        2                      3
# \phi_2} ⋅{\phi_2}_{x}  - 3⋅σ₁ ⋅{\phi_1}_{xx}⋅{\phi_2}  - 30⋅σ₁ ⋅{\phi_1}_{x}⋅{\phi_2} ⋅{\ph
#
#
#
#                2         4                         2         4                       2
# i_2}_{x} + 9⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{xxxxx} + 27⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{xx} + 126⋅σ₁ ⋅{\ph
#
#
#
#     3                                      2         3
# i_2} ⋅{\phi_2}_{xxxx}⋅{\phi_2}_{x} + 198⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{xxx}⋅{\phi_2}_{xx} + 108⋅σ
#
#
#
#  2         3             2         2         2                            2         2
# ₁ ⋅{\phi_2} ⋅{\phi_2}_{x}  + 522⋅σ₁ ⋅{\phi_2} ⋅{\phi_2}_{xxx}⋅{\phi_2}_{x}  + 666⋅σ₁ ⋅{\phi
#
#
#
#    2              2                      2                                    3        2
# _2} ⋅{\phi_2}_{xx} ⋅{\phi_2}_{x} + 792⋅σ₁ ⋅{\phi_2}⋅{\phi_2}_{xx}⋅{\phi_2}_{x}  + 72⋅σ₁ ⋅{\
#
#
#                            2                                2                             2
#           5   3⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{xxxx}   5⋅σ₁⋅{\phi_1} ⋅{\phi_1}_{x}   3⋅σ₁⋅{\phi_1}
# phi_2}_{x}  - ────────────────────────────── - ─────────────────────────── + ──────────────
#                             2                               2                             2
#
#
# ⋅{\phi_2}_{x}                                                                          2
# ───────────── - 9⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xxx}⋅{\phi_1}_{x} - 6⋅σ₁⋅{\phi_1}⋅{\phi_1}_{xx}  +
#
#
#
#
# 3⋅σ₁⋅{\phi_1}⋅{\phi_1}_{x}⋅{\phi_2} - 3⋅σ₁⋅{\phi_1}⋅{\phi_2}⋅{\phi_2}_{xxxx} - 7⋅σ₁⋅{\phi_1
#
#
#
#
# }⋅{\phi_2}⋅{\phi_2}_{x} - 6⋅σ₁⋅{\phi_1}⋅{\phi_2}_{xxx}⋅{\phi_2}_{x} - 3⋅σ₁⋅{\phi_1}⋅{\phi_2
#
#
#                                        2
#       2   3⋅σ₁⋅{\phi_1}_{xxxx}⋅{\phi_2}
# }_{xx}  - ────────────────────────────── - 6⋅σ₁⋅{\phi_1}_{xxx}⋅{\phi_2}⋅{\phi_2}_{x} - 12⋅σ
#                         2
#
#
#                             2
# ₁⋅{\phi_1}_{xx}⋅{\phi_1}_{x}  - 6⋅σ₁⋅{\phi_1}_{xx}⋅{\phi_2}⋅{\phi_2}_{xx} - 6⋅σ₁⋅{\phi_1}_{
#
#
#                                               2
#                 2   7⋅σ₁⋅{\phi_1}_{x}⋅{\phi_2}
# xx}⋅{\phi_2}_{x}  - ─────────────────────────── - 6⋅σ₁⋅{\phi_1}_{x}⋅{\phi_2}⋅{\phi_2}_{xxx}
#                                  2
#
#                                                                 2
#                                                    3⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{xxxxxxx}
#  - 12⋅σ₁⋅{\phi_1}_{x}⋅{\phi_2}_{xx}⋅{\phi_2}_{x} + ───────────────────────────────── + 6⋅σ₁
#                                                                    2
#
#                                            2
#          2                   17⋅σ₁⋅{\phi_2} ⋅{\phi_2}_{x}
# ⋅{\phi_2} ⋅{\phi_2}_{xxxx} + ──────────────────────────── + 12⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xxxxxx
#                                           2
#
#
#
# }⋅{\phi_2}_{x} + 27⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xxxxx}⋅{\phi_2}_{xx} + 42⋅σ₁⋅{\phi_2}⋅{\phi_2}_{x
#
#
#
#
# xxx}⋅{\phi_2}_{xxx} + 27⋅σ₁⋅{\phi_2}⋅{\phi_2}_{xxx}⋅{\phi_2}_{x} + 15⋅σ₁⋅{\phi_2}⋅{\phi_2}_
#
#
#
#     2                                      2
# {xx}  + 27⋅σ₁⋅{\phi_2}_{xxxxx}⋅{\phi_2}_{x}  + 117⋅σ₁⋅{\phi_2}_{xxxx}⋅{\phi_2}_{xx}⋅{\phi_2
#
#
#
#                             2                                                   2
# }_{x} + 75⋅σ₁⋅{\phi_2}_{xxx} ⋅{\phi_2}_{x} + 108⋅σ₁⋅{\phi_2}_{xxx}⋅{\phi_2}_{xx}  + 30⋅σ₁⋅{
#
#
#
#                          2   {\phi_1}   {\phi_1}_{xxxxxx}   {\phi_1}_{xxx}   {\phi_2}   {\p
# \phi_2}_{xx}⋅{\phi_2}_{x}  - ──────── - ───────────────── - ────────────── + ──────── + ───
#                                 3               4                 2             3
#
#
# hi_2}_{xxxxxxxxx}   {\phi_2}_{xxxxxx}   {\phi_2}_{xxx}
# ───────────────── + ───────────────── + ──────────────
#       12                    4                 2
# 6
# 155
